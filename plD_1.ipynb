# %%
# !pip install tensorflow

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd /content/gdrive/MyDrive/Colab Notebooks/PltryDD
# Out:
# /content/gdrive/MyDrive/Colab Notebooks/PltryDD

# %%
# !python Pdc.py
# Out:
# 2023-12-16 12:38:34.967876: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-16 12:38:34.967929: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-16 12:38:34.969225: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-16 12:38:34.976304: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
class_names=['cocci','healthy','ncd','salmo']
import numpy as np
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image
model=load_model('plD_vgg19.h5')
img=image.load_img('/content/gdrive/MyDrive/Colab Notebooks/PltryDD/plD/salmo/salmo.1006.jpg',target_size=(224,224))
x=image.img_to_array(img)
x
x.shape
x=x/255

# %%
from tensorflow.keras.applications.vgg16 import preprocess_input
x=np.expand_dims(x,axis=0)
img_data=preprocess_input(x)
img_data.shape
model.predict(img_data)
a=np.argmax(model.predict(img_data), axis=1)[0]
c=class_names[a]
c
# Out:
# ...
# 1/1 [==============================] - 0s 27ms/step
# 'cocci'

# %%
import os
import numpy as np
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image

# Load the model
model = load_model('plD_vgg19.h5')

# Class names
class_names = ['cocci', 'healthy', 'ncd', 'salmo']

# Path to the directory containing test images
test_dir = '/content/gdrive/MyDrive/Colab Notebooks/PltryDD/plD/'

# Iterate through images in the directory
for class_name in class_names:
    class_dir = os.path.join(test_dir, class_name)
    for img_file in os.listdir(class_dir):
        img_path = os.path.join(class_dir, img_file)
        img = image.load_img(img_path, target_size=(224, 224))
        x = image.img_to_array(img)
        x = x / 255.0  # Normalize
        x = np.expand_dims(x, axis=0)

        # Predict
        predictions = model.predict(x)
        predicted_class = class_names[np.argmax(predictions)]

        # Print predictions for debugging
        print(f"Image: {img_file}, Predicted: {predicted_class}, True Class: {class_name}")
# Out:
# Streaming output truncated to the last 5000 lines.
# 1/1 [==============================] - 0s 33ms/step
# Image: ncd.238.jpg, Predicted: salmo, True Class: ncd
# 1/1 [==============================] - 0s 38ms/step
# Image: ncd.239.jpg, Predicted: ncd, True Class: ncd
# 1/1 [==============================] - 0s 37ms/step
# Image: ncd.236.jpg, Predicted: ncd, True Class: ncd
# 1/1 [==============================] - 0s 30ms/step
# Image: ncd.241.jpg, Predicted: salmo, True Class: ncd
# 1/1 [==============================] - 0s 28ms/step
# Image: ncd.233.jpg, Predicted: ncd, True Class: ncd
# 1/1 [==============================] - 0s 42ms/step
# Image: ncd.24.jpg, Predicted: ncd, True Class: ncd
# 1/1 [==============================] - 0s 36ms/step
# Image: ncd.235.jpg, Predicted: ncd, True Class: ncd
# 1/1 [==============================] - 0s 32ms/step
# Image: ncd.240.jpg, Predicted: ncd, True Class: ncd
# 1/1 [==============================] - 0s 27ms/step
# ...
